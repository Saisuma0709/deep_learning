# %%
import pandas as pd

# read data
# clean data ( check for 0 values and NA )
# preprocess data (replacing erroneous values with proper values)

# %%
diabetes_data = pd.read_csv('diabetes.csv')

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes_data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes_data.duplicated().sum()
# Out:
# 0

# %%
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes_data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes_data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Loading the daibetes dataset
diabetes_data = pd.read_csv('diabetes.csv')

# Computing the correlation matrix
correlation_matrix = diabetes_data.corr()

correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5fce3_row0_col0, #T_5fce3_row1_col1, #T_5fce3_row2_col2, #T_5fce3_row3_col3, #T_5fce3_row4_col4, #T_5fce3_row5_col5, #T_5fce3_row6_col6, #T_5fce3_row7_col7, #T_5fce3_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5fce3_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_5fce3_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_5fce3_row0_col3, #T_5fce3_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_5fce3_row0_col4, #T_5fce3_row0_col5, #T_5fce3_row0_col6, #T_5fce3_row2_col8, #T_5fce3_row3_col0, #T_5fce3_row3_col1, #T_5fce3_row3_col7, #T_5fce3_row6_col2, #T_5fce3_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5fce3_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_5fce3_row0_col8, #T_5fce3_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_5fce3_row1_col0 {
#   background-color: #799cf8;
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Listing the columns which you need to check
columns_to_plot = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Coloring the  map based on the 'Outcome' column (0 for non-diabetic, 1 for diabetic)
colors = {0: 'blue', 1: 'red'}

# Creating scatter plots for each pair of columns
plt.figure(figsize=(10, 6))  # Setting the figure size
n = len(columns_to_plot)

# Creating a scatter plot matrix
for i in range(n):
    for j in range(i+1, n):
        plt.subplot(n-1, n-1, (i*(n-1)) + j)
        plt.scatter(diabetes_data[columns_to_plot[i]], diabetes_data[columns_to_plot[j]], 
                    c=diabetes_data['Outcome'].map(colors), alpha=0.6, edgecolor='w')
        plt.xlabel(columns_to_plot[i])
        plt.ylabel(columns_to_plot[j])

# Show the plot
plt.tight_layout()
plt.show()

# %%
diabetes_data = pd.DataFrame(diabetes_data)
corr = diabetes_data.corr()
corr.style.background_gradient(cmap='coolwarm')
#checking the values which are negative and impacting the perceptron model
# Out:
# <style type="text/css">
# #T_35399_row0_col0, #T_35399_row1_col1, #T_35399_row2_col2, #T_35399_row3_col3, #T_35399_row4_col4, #T_35399_row5_col5, #T_35399_row6_col6, #T_35399_row7_col7, #T_35399_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_35399_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_35399_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_35399_row0_col3, #T_35399_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_35399_row0_col4, #T_35399_row0_col5, #T_35399_row0_col6, #T_35399_row2_col8, #T_35399_row3_col0, #T_35399_row3_col1, #T_35399_row3_col7, #T_35399_row6_col2, #T_35399_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_35399_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_35399_row0_col8, #T_35399_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_35399_row1_col0 {
#   background-color: #799cf8;
# ...

# %%
# Replacing 0 values in relevant columns with NaN for making the data easy to handle
cleaned_data = diabetes_data.copy()
columns_with_zero = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Replacing 0 values with NaN for these columns to handle the  missing data
cleaned_data[columns_with_zero] = cleaned_data[columns_with_zero].replace(0, pd.NA)

# Checking how many values are missing in the columns
na_values = cleaned_data.isna().sum()

na_values
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

# Loading the dataset
diabetes_data = pd.read_csv('diabetes.csv')

# Defining the columns where 0 values are considered to be missing
columns_with_zero = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Step 1: Data Cleaning (Replace 0 values with NaN and then impute with the median)
diabetes_data[columns_with_zero] = diabetes_data[columns_with_zero].replace(0, np.nan)

# Imputing missing values (NaNs) with the median of each column
for col in columns_with_zero:
    diabetes_data[col].fillna(diabetes_data[col].median(), inplace=True)

#Data Preprocessing (Scaling using Min-Max Scaler)
# Separating features and outcome to predict the data
x = diabetes_data.drop(columns=['Outcome'])  
y = diabetes_data['Outcome']  
# Min-Max scaling 
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(X)

#Spliting the data into training and testing sets (80% training set, 20% testing set)
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=35)

# Training the Perceptron Model
perceptron_model = Perceptron(max_iter=1000, eta0=1.0, random_state=35)
perceptron_model.fit(x_train, y_train)

#Making Predictions on the Test Set
y_pred = perceptron_model.predict(x_test)

# Evaluating the Model 
accuracy = accuracy_score(y_test, y_pred)
print(f"Perceptron Model Accuracy: {accuracy * 100:.2f}%")

#  Displaying the first few predictions along with actual outcomes of the dataset
for i in range(20):  # Displaying 20 predictions for example
    print(f"Test case {i+1}: Predicted = {y_pred[i]}, Actual = {y_test.iloc[i]}")



parameter_grid = {
    'penalty': [None, 'l2', 'l1', 'elasticnet'],  # regularization
    'alpha': [0.0001, 0.001, 0.01],              # Regularization strength
    'max_iter': [1000, 2000, 5000],               # Number of iterations
    'eta0': [0.1, 1.0, 10.0]                     # learning rates
}

# Grid Search for Hyperparameter Tuning to get optimiseed accuracy
grid_search = GridSearchCV(perceptron, parameter_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Fitting the grid search to the training data
grid_search.fit(X_train, y_train)

# Best Parameters and Score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f"Best Parameters: {best_params}")
print(f"Best Cross-Validation Accuracy: {best_score * 100:.2f}%")

# Evaluating the Model with Best Parameters on the Test Set
best_model = grid_search.best_estimator_

# Making predictions on the test set
y_pred = best_model.predict(X_test)

plt.figure(figsize=(12, 6))

# Before Cleaning
plt.subplot(1, 2, 1)
for col in columns_with_zero:
    diabetes_data[col].plot(kind='kde', label=col)  # KDE plot for each column
plt.title("KDE Plot Before Cleaning")
plt.legend()

# Step 4: Plot KDE (Curve Graph) After Cleaning
plt.subplot(1, 2, 2)
for col in columns_with_zero:
    diabetes_data_cleaned[col].plot(kind='kde', label=col)  # KDE plot for each scaled column
plt.title("KDE Plot After Cleaning (Scaled)")
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# Perceptron Model Accuracy: 73.38%
# Test case 1: Predicted = 0, Actual = 1
# Test case 2: Predicted = 1, Actual = 1
# Test case 3: Predicted = 0, Actual = 0
# Test case 4: Predicted = 0, Actual = 0
# Test case 5: Predicted = 0, Actual = 0
# Test case 6: Predicted = 0, Actual = 0
# Test case 7: Predicted = 0, Actual = 0
# Test case 8: Predicted = 0, Actual = 0
# Test case 9: Predicted = 0, Actual = 1
# Test case 10: Predicted = 0, Actual = 0
# Test case 11: Predicted = 0, Actual = 0
# Test case 12: Predicted = 0, Actual = 0
# Test case 13: Predicted = 1, Actual = 0
# Test case 14: Predicted = 1, Actual = 1
# Test case 15: Predicted = 1, Actual = 1
# Test case 16: Predicted = 1, Actual = 1
# Test case 17: Predicted = 0, Actual = 0
# Test case 18: Predicted = 1, Actual = 0
# Test case 19: Predicted = 0, Actual = 0
# Test case 20: Predicted = 0, Actual = 0
# Best Parameters: {'alpha': 0.001, 'eta0': 10.0, 'max_iter': 1000, 'penalty': 'l1'}
# Best Cross-Validation Accuracy: 75.09%
